# %%
import pandas as pd
import numpy as np

# %%
path='C:/Users/Administrator/Desktop/Data science/DATATHON/Datathon/data/data.csv'
data=pd.read_csv(path,delimiter=';',encoding='latin')

# %%
data.shape
# Out:
# (30091754, 16)

# %%
data5=data.head(5)
data5
# Out:
#            DATETIME                        RAVEN_NAME FAMILY_NAME  \
# 0  2018-07-06 10:15   Razzle Dazzle Rose raven Shadow   Targerian
# 1  2018-07-06 19:30          Tiny Insolent raven Lulu   Targerian
# 2  2018-07-06 18:30     Blithe And Beautiful raven Mo   Targerian
# 3  2018-07-06 00:45  Illuminating Emerald raven Daffy   Lannister
# 4  2018-07-06 12:00     Blithe And Beautiful raven Mo     Greyjoy
#
#      MEMBER_NAME NETWORK  FIRST_GET_RESPONSE_SUCCESS_D  PAGE_BROWSING_DELAY  \
# 0  Maester Aemon      2g                           644                 2832
# 1  Maester Aemon      4g                           258                51752
# 2        Rheagar      3g                          1094                19562
# 3          Kevan      2g                           432                 1488
# 4          Theon      4g                          1094                25132
#
#    TCP_SETUP_TOTAL_DELAY  PAGE_CONTENT_DOWNLOAD_TOTAL_D  \
# ...

# %%
print(data.columns)
print(num_type)
# Out:
# Index(['DATETIME', 'RAVEN_NAME', 'FAMILY_NAME', 'MEMBER_NAME', 'NETWORK',
#        'FIRST_GET_RESPONSE_SUCCESS_D', 'PAGE_BROWSING_DELAY',
#        'TCP_SETUP_TOTAL_DELAY', 'PAGE_CONTENT_DOWNLOAD_TOTAL_D',
#        'FIRST_DNS_RESPONSE_SUCCESS_D', 'DNS_RESPONSE_SUCCESS_DELAY',
#        'FIRST_TCP_RESPONSE_SUCCESS_D', 'PAGE_SR_DELAYS', 'SYN_SYN_DELAY',
#        'TCP_CONNECT_DELAY', 'PAGE_BROWSING_DELAYS'],
#       dtype='object')
# ['FIRST_GET_RESPONSE_SUCCESS_D', 'PAGE_BROWSING_DELAY', 'TCP_SETUP_TOTAL_DELAY', 'PAGE_CONTENT_DOWNLOAD_TOTAL_D', 'FIRST_DNS_RESPONSE_SUCCESS_D', 'DNS_RESPONSE_SUCCESS_DELAY', 'FIRST_TCP_RESPONSE_SUCCESS_D', 'PAGE_SR_DELAYS', 'SYN_SYN_DELAY', 'TCP_CONNECT_DELAY', 'PAGE_BROWSING_DELAYS']

# %%
data1=data.query('FIRST_GET_RESPONSE_SUCCESS_D !=0 & PAGE_BROWSING_DELAY !=0 & TCP_SETUP_TOTAL_DELAY !=0 & PAGE_CONTENT_DOWNLOAD_TOTAL_D !=0 & FIRST_DNS_RESPONSE_SUCCESS_D !=0 & DNS_RESPONSE_SUCCESS_DELAY !=0 & FIRST_TCP_RESPONSE_SUCCESS_D !=0 & PAGE_SR_DELAYS !=0 & SYN_SYN_DELAY !=0 & TCP_CONNECT_DELAY !=0 & PAGE_BROWSING_DELAYS !=0').head(5)

# %%
data1.groupby(FAMILY_NAME).count().sort_values(ascending=False)

# %%
data[["FAMILY_NAME","MEMBER_NAME"]]
# Out:
#          FAMILY_NAME           MEMBER_NAME
# 0          Targerian         Maester Aemon
# 1          Targerian         Maester Aemon
# 2          Targerian               Rheagar
# 3          Lannister                 Kevan
# 4            Greyjoy                 Theon
# 5            Greyjoy                 Aeron
# 6            Baelish         Petyr Baelish
# 7          Lannister                Cersei
# 8          Targerian         Maester Aemon
# 9            Greyjoy                 Balon
# 10           Baelish         Petyr Baelish
# 11           Baelish         Petyr Baelish
# 12         Lannister                Tyrion
# 13           Greyjoy                 Aeron
# 14         Targerian         Maester Aemon
# 15         Targerian              Deanerys
# 16           Baelish         Petyr Baelish
# 17         Lannister       Maester Pycelle
# 18         Lannister                 Kevan
# 19             Stark                Benjen
# 20             Stark                  Robb
# ...

# %%
data10.describe()
# Out:
#        FIRST_GET_RESPONSE_SUCCESS_D  PAGE_BROWSING_DELAY  \
# count                       5.00000              5.00000
# mean                      704.40000          20153.20000
# std                       381.01811          20445.26711
# min                       258.00000           1488.00000
# 25%                       432.00000           2832.00000
# 50%                       644.00000          19562.00000
# 75%                      1094.00000          25132.00000
# max                      1094.00000          51752.00000
#
#        TCP_SETUP_TOTAL_DELAY  PAGE_CONTENT_DOWNLOAD_TOTAL_D  \
# count               5.000000                        5.00000
# mean              792.800000                    16577.20000
# std               741.448043                    20772.25022
# min               260.000000                      638.00000
# 25%               470.000000                      730.00000
# 50%               558.000000                    13054.00000
# ...

# %%
dict(data.dtypes)
# Out:
# {'DATETIME': dtype('O'),
#  'DNS_RESPONSE_SUCCESS_DELAY': dtype('int64'),
#  'FAMILY_NAME': dtype('O'),
#  'FIRST_DNS_RESPONSE_SUCCESS_D': dtype('int64'),
#  'FIRST_GET_RESPONSE_SUCCESS_D': dtype('int64'),
#  'FIRST_TCP_RESPONSE_SUCCESS_D': dtype('int64'),
#  'MEMBER_NAME': dtype('O'),
#  'NETWORK': dtype('O'),
#  'PAGE_BROWSING_DELAY': dtype('int64'),
#  'PAGE_BROWSING_DELAYS': dtype('int64'),
#  'PAGE_CONTENT_DOWNLOAD_TOTAL_D': dtype('int64'),
#  'PAGE_SR_DELAYS': dtype('int64'),
#  'RAVEN_NAME': dtype('O'),
#  'SYN_SYN_DELAY': dtype('int64'),
#  'TCP_CONNECT_DELAY': dtype('int64'),
#  'TCP_SETUP_TOTAL_DELAY': dtype('int64')}

# %%
num_type=[key for key in dict(data.dtypes) if dict(data.dtypes)[key] in ['int64']]
print(num_type)
cat_type=[key for key in dict(data.dtypes) if dict(data.dtypes)[key] in ['O']]
print(cat_type)
num_data=data[num_type]
cat_data=data[cat_type]
num_data10=num_data.head(10)
cat_data10=cat_data.head(10)
# Out:
# ['FIRST_GET_RESPONSE_SUCCESS_D', 'PAGE_BROWSING_DELAY', 'TCP_SETUP_TOTAL_DELAY', 'PAGE_CONTENT_DOWNLOAD_TOTAL_D', 'FIRST_DNS_RESPONSE_SUCCESS_D', 'DNS_RESPONSE_SUCCESS_DELAY', 'FIRST_TCP_RESPONSE_SUCCESS_D', 'PAGE_SR_DELAYS', 'SYN_SYN_DELAY', 'TCP_CONNECT_DELAY', 'PAGE_BROWSING_DELAYS']
# ['DATETIME', 'RAVEN_NAME', 'FAMILY_NAME', 'MEMBER_NAME', 'NETWORK']

# %%
num_data10.head()
# Out:
#    FIRST_GET_RESPONSE_SUCCESS_D  PAGE_BROWSING_DELAY  TCP_SETUP_TOTAL_DELAY  \
# 0                           644                 2832                   2100
# 1                           258                51752                    260
# 2                          1094                19562                    470
# 3                           432                 1488                    558
# 4                          1094                25132                    576
#
#    PAGE_CONTENT_DOWNLOAD_TOTAL_D  FIRST_DNS_RESPONSE_SUCCESS_D  \
# 0                            730                             2
# 1                          51334                             0
# 2                          17130                             4
# 3                            638                           272
# 4                          13054                             4
#
#    DNS_RESPONSE_SUCCESS_DELAY  FIRST_TCP_RESPONSE_SUCCESS_D  PAGE_SR_DELAYS  \
# ...
